# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model_name = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

translator = pipeline('translation', model=model, tokenizer=tokenizer, max_length=400)

def translate_text(text, source_lang='eng_Latn', target_lang='kan_Knda'):
    return translator(text, src_lang=source_lang, tgt_lang=target_lang)[0]['translation_text']

input_text = "Artificial Intelligence is transforming the future of education and healthcare."

translated_kannada = translate_text(input_text, target_lang='kan_Knda')

print("Original English Text:\n", input_text, "\n")

print("Kannada Translation:\n", translated_kannada, "\n")
# Out:
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# Device set to use cuda:0
# Original English Text:
#  Artificial Intelligence is transforming the future of education and healthcare.
#
# Kannada Translation:
#  ಕೃತಕ ಬುದ್ಧಿಮತ್ತೆಯು ಶಿಕ್ಷಣ ಮತ್ತು ಆರೋಗ್ಯದ ಭವಿಷ್ಯವನ್ನು ಪರಿವರ್ತಿಸುತ್ತಿದೆ.

# %%
translated_hindi = translate_text(input_text, target_lang='hin_Deva')
translated_telugu = translate_text(input_text, target_lang='tel_Telu')
print("Original English Text:\n", input_text, "\n")
print("Hindi Translation:\n", translated_hindi, "\n")
print("Telugu Translation:\n", translated_telugu)
# Out:
# Original English Text:
#  Artificial Intelligence is transforming the future of education and healthcare.
#
# Hindi Translation:
#  आर्टिफिशियल इंटेलिजेंस शिक्षा और स्वास्थ्य सेवा के भविष्य को बदल रहा है।
#
# Telugu Translation:
#  ఆర్టిఫిషియల్ ఇంటెలిజెన్స్ విద్య, ఆరోగ్య సంరక్షణ భవిష్యత్తును మారుస్తోంది.
